# %% [markdown]
# * 上課錄影1 https://www.youtube.com/watch?v=fyI2xnVGFfI
# * 上課錄影2 https://www.youtube.com/watch?v=JRGaB19394c
# * 講義 https://github.com/roberthsu2003/
# * Docker https://www.docker.com/
# * 作業一 https://www.markdowntutorial.com/zh-tw/

# %%
print('Hello! Python!')
# Out:
# Hello! Python!

# %% [markdown]
# ## 數學運算
# * 講義 https://github.com/roberthsu2003/python/tree/master/%E6%95%B8%E5%80%BC%E8%A8%88%E7%AE%97%E8%88%87%E8%B3%87%E6%96%99%E8%BC%B8%E5%85%A5

# %%
print('加法:',5+8) #statement/express(敘述)
print('減法:',90-10)
print('乘法:',4*7)
print('除法(float):',7/2)
print('除法(int):',7//2)
print('餘數:',7%3)
print('平方:',2**3)
# Out:
# 加法: 13
# 減法: 80
# 乘法: 28
# 除法(float): 3.5
# 除法(int): 3
# 餘數: 1
# 平方: 8

# %%
print(2*(1+2)**2-2**2*2)
# Out:
# 10
